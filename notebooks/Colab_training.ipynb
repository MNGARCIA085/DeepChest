# %% [markdown]
# **DEEP CHEST (Training)**

# %%
# Mount drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# set data root
import os
os.environ["DATA_ROOT"] = "/content/drive/MyDrive/data/nih"

# %%
# clone project
# !git clone https://github.com/MNGARCIA085/DeepChest
# %cd DeepChest
# Out:
# fatal: destination path 'DeepChest' already exists and is not an empty directory.
# /content/DeepChest

# %%
# Install repo as a package (editable mode)
# !pip install -e .
# Out:
# Obtaining file:///content/DeepChest
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for deep_chest (pyproject.toml) ... done
#   Created wheel for deep_chest: filename=deep_chest-0.1.0-0.editable-py3-none-any.whl size=1253 sha256=895b60d8d8559cfc50a83a49975367a60b7c9184a43cf9ae5cad4f4d6cdd0129
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zgy3qs_k/wheels/62/bb/fc/e5f8fdb1824869a2072a2f3cad67e95e04387d5d3d73d05136
# Successfully built deep_chest
# ...
#   Attempting uninstall: deep_chest
#     Found existing installation: deep_chest 0.1.0
#     Uninstalling deep_chest-0.1.0:
#       Successfully uninstalled deep_chest-0.1.0
# ...

# %%
# !python -m scripts.training model_type=cnn tracking.enabled=false model_type.training.phase1.epochs=1
# Out:
# 2026-02-23 19:10:13.280128: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-23 19:10:13.327494: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-02-23 19:10:20,509][__name__][INFO] - setup plugin alembic.autogenerate.schemas
# [2026-02-23 19:10:20,510][__name__][INFO] - setup plugin alembic.autogenerate.tables
# [2026-02-23 19:10:20,510][__name__][INFO] - setup plugin alembic.autogenerate.types
# [2026-02-23 19:10:20,510][__name__][INFO] - setup plugin alembic.autogenerate.constraints
# [2026-02-23 19:10:20,511][__name__][INFO] - setup plugin alembic.autogenerate.defaults
# [2026-02-23 19:10:20,511][__name__][INFO] - setup plugin alembic.autogenerate.comments
# ...
