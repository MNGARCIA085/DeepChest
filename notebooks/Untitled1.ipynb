# %%
trial = {
    "p1": {
            "h": {
                "a":2,
                "b":3
            },
            "c":7,
    },
    "p2": {
            "h": {
                "a":2,
                "b":3
            },
            "c":7,
    },
    
}

# %%
for t in trial:
    print(t)
    for a in t:
        print(a.h)
# Out:
# p1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [6], line 4
#       2 print(t)
#       3 for a in t:
# ----> 4     print(a.h)
#
# AttributeError: 'str' object has no attribute 'h'
